# %% [markdown]
# # Homework 1: Exploring a New Score with Music21
#
# **Digital Musicology**
#
# ---
#
# **Estimated time:** 3–4 hours
# **Submission:** Upload your completed notebook to Moodle by our next meeting (23 March 14:30)
#
# ---
#
# ## Instructions
#
# In this homework you will independently apply the skills you learned in Practice Session 1 to a different piece from the music21 corpus. You will work with a **Mozart quartet** instead of a Bach chorale.
#
# **You are encouraged to use AI tools** (Gemini in Colab, ChatGPT, Claude, etc.) to help generate code. However:
# - You must **read and understand** the code before submitting it.
# - Each task asks you to **explain what you observe** in your own words — the AI cannot do this for you.
# - When you use an AI tool to generate code for a task, **note what prompt you gave it** (a brief note is fine).
#
# **The piece:** Mozart's String Quartet No. 2 in D major, K. 155, first movement. In music21, you can access it as:
# ```python
# corpus.parse('mozart/k331/k331_1')
# ```
#
# ---

# %% [markdown]
# ## Setup
#
# Run the cells below to install and import music21. Do this before attempting any of the tasks.

# %%
#Here we will setup our virtual environment so that we can use music21, print out scores and play music
# %%capture
# !pip install music21 --quiet

import music21
# Install MuseScore – needed to display graphical notation
# !add-apt-repository ppa:mscore-ubuntu/mscore-stable -y
# !apt-get update
# !apt-get install musescore

us = music21.environment.UserSettings()
us['musescoreDirectPNGPath'] = '/usr/bin/mscore'
us['directoryScratch'] = '/tmp'

#this line installs software for the underlying operating system of your virtual machine (linux)
# !apt-get install -y fluidsynth fluid-soundfont-gm
#this line installs the python library working with this underlying library
# !pip install pretty_midi pyfluidsynth

# %% [markdown]
# ### **Do not forget to restart your runtime here!**

# %% [markdown]
# ---
# ## Task 1 — Load and inspect the score (1/6 points)
#
# In this homework we will work with Mozart's String Quartet No. 2 in D major, K. 155

# %%
from music21 import *
from collections import Counter
print("Ready!")

# %%
# Load the Mozart quartet movement 1
quartet = corpus.parse('mozart/k155/movement1.mxl')
print("Score loaded successfully.")

# %%
# Save the current quartet object to a MusicXML file
quartet.write('musicxml', fp='quartet.mxl')

# %% [markdown]
# <div style="border: 2px solid #4A90D9; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f0f7ff;">
# <b>✏️ Task 1a — Basic metadata</b><br><br>
# Write code to print the following information about the quartet:<br>
# <ul>
# <li>Which instruments is the quartet written for?</code>)</li>
# <li>The number of measures in the score (hint: use <code>getElementsByClass('Measure')</code> on one of the parts)</li>
# <li> Find metadata field Software. Which software was this piece written with?</li>
# </ul>
# </div>

# %% [markdown]
# **Your answers (fill in the text below):**
#
# - Instruments:
# - Number of measures:
# - Software:

# %% [markdown]
# <div style="border: 2px solid #4A90D9; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f0f7ff;">
# <b>✏️ Task 1b — Examine the time signature and tempo</b><br><br>
# Use the Gemini button or another AI tool with this prompt:<br><br>
# <i>"Using music21 Python, given a variable <code>quartet</code> containing a parsed score, write code to find and print the time signature and any dynamics markings present in the score. Add a comment to each line."</i><br><br>
# Paste and run the generated code below. Note what AI tool you used and your prompt.
# </div>

# %% [markdown]
# **Describe what you found:**
# What is the time signature? Is this movement in a simple or compound meter? What do the dynamics markings suggest? Press "transform code" and modify your prompt to get more useful information about the dynamic markings (e.g., how many of which type, do they change towards the end etc).
#
# *Your answer here:*

# %% [markdown]
# ---
# ## Task 2 — Display the score (1/6 points)

# %% [markdown]
# <div style="border: 2px solid #4A90D9; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f0f7ff;">
# <b>✏️ Task 2a — Display the opening theme</b><br><br>
# Display measures 1 through 8 of the score as notation (use <code>.measures(1, 8)</code> followed by <code>.show()</code> or <code>.show('text')</code>).<br><br>
# If <code>.show()</code> does not produce graphical notation in your Colab session, use <code>.show('text')</code> — it shows a text-based representation that lists every note and its properties.
# </div>

# %%
# Display measures 1-8

# %% [markdown]
# ---
# ## Task 3 — Pitch analysis (1/6 points)

# %% [markdown]
# <div style="border: 2px solid #4A90D9; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f0f7ff;">
# <b>✏️ Task 3a — Pitch frequency in the right hand (melody)</b><br><br>
# Adapt the pitch frequency counting code from Practice 1 to count pitch classes in the <b>Violin 1</b> of the quartet. Print the results from most to least frequent.<br><br>
# </div>

# %% [markdown]
# **Interpretation:**
# What are the three most frequent pitch classes? Does this match what you would expect given that the piece is in D major? Explain briefly.
#
# *Your answer here:*

# %% [markdown]
# <div style="border: 2px solid #4A90D9; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f0f7ff;">
# <b>✏️ Task 3b — Automatic key estimation</b><br><br>
# Use <code>quartet.analyze('key')</code> to let music21 estimate the key automatically. Print the tonic, mode, and the confidence score (<code>correlationCoefficient</code>).<br><br>
# The piece is in D major — does music21 get it right? What does the confidence score suggest?
# </div>

# %%
# Key estimation

# %% [markdown]
# **Your answer:**
#
# *Your answer here:*

# %% [markdown]
# ---
# ## Task 4 — Rhythm analysis (1/6 points)

# %% [markdown]
# <div style="border: 2px solid #4A90D9; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f0f7ff;">
# <b>✏️ Task 4a — Duration frequency</b><br><br>
# Write code (with AI help if needed) that counts how many times each note duration appears in the right hand melody. Duration in music21 is stored as <code>note.duration.quarterLength</code> — a number where 1.0 = quarter note, 2.0 = half note, 0.5 = eighth note, etc.<br><br>
# <b>Suggested prompt for the AI:</b><br>
# <i>"Using Python and music21, given a variable <code>quartet</code> with a parsed score, count how many times each note duration (in quarter note units) appears in the first part. Sort the results from most to least frequent and print them. Add comments."</i>
# </div>

# %% [markdown]
# **Interpretation:**
# Which duration is most common? Does this match the 3/4 time signature of the piece? What does the prevalence of this duration tell you about the rhythmic character of the melody?
#
# *Your answer here:*

# %% [markdown]
# <div style="border: 2px solid #4A90D9; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f0f7ff;">
# <b>✏️ Task 4b — Average note duration</b><br><br>
# Calculate the average duration of notes in the melody. You can do this by summing all durations and dividing by the total number of notes — or you can ask the AI to generate this code for you. Show your work in the code cell below.
# </div>

# %%
# Average note duration

# %% [markdown]
# **Does the average duration confirm or complicate your answer to Task 4a? Explain briefly.**
#
# *Your answer here:*

# %% [markdown]
# ---
# ## Task 5 — Open exploration (2/6 points)
#
# This task is open-ended. Choose **one** of the options below and carry it out.

# %% [markdown]
# <div style="border: 2px solid #4A90D9; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f0f7ff;">
# <b>✏️ Task 5 — Choose one option</b><br><br>
#
# <b>Option A — Compare two parts:</b><br>
# Repeat the pitch frequency analysis for <i>two</i> movements of the quartet. Write 3–4 sentences comparing the two distributions. What does this tell you about these two movements?
# <br><br>
# <b>Option B — Explore a different piece:</b><br>
# Choose a different piece from the music21 corpus (see https://music21.org/music21docs/about/referenceCorpus.html#referencecorpus) or from any source you find yourself. Load it, display the first 8 measures, and do an analysis of your choice on it. Write 4–5 sentences about it.
# <br><br>
# <b>Option C — Interval analysis:</b><br>
# Use the AI to help you write code that extracts the intervals between consecutive notes in the melody (the distance between note N and note N+1). Count how often each interval type appears. Which intervals are most common? What does this tell you about the melodic style of the piece?
# <br><br>
# </div>

# %% [markdown]
# **I chose Option:** ___

# %% [markdown]
# **Your written analysis (3–5 sentences):**
#
# *Your answer here:*

# %% [markdown]
# ---
# ## Reflection Questions
#
# Answer the following questions briefly in the text cells below. There are no wrong answers — these questions are about your learning process.

# %% [markdown]
# <div style="border: 2px solid #888; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f9f9f9;">
# <b>Reflection 1</b><br><br>
# Describe one moment where AI-generated code did <i>not</i> work as expected. What error or unexpected result did you get? How did you fix it?
# </div>

# %% [markdown]
# *Your answer here:*

# %% [markdown]
# <div style="border: 2px solid #888; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f9f9f9;">
# <b>Reflection 2</b><br><br>
# Which of the analyses in this homework do you find most musically meaningful? Why? Is there something about the Mozart quartet that the code was <i>not</i> able to capture, which you noticed by ear or eye?
# </div>

# %% [markdown]
# *Your answer here:*

# %% [markdown]
# <div style="border: 2px solid #888; border-radius: 6px; padding: 12px; margin: 10px 0; background-color: #f9f9f9;">
# <b>Reflection 3</b><br><br>
# What question about a piece would you like to investigate computationally, but did not have the tools or time to do here? Describe it in 2–3 sentences.
# </div>

# %% [markdown]
# *Your answer here:*

# %% [markdown]
# **Save your notebook** (File → Save, or Ctrl+S) and download it as `.ipynb` (File → Download → Download .ipynb) before submitting.
